# %% [markdown]
# #### Exploratory Data Analysis

# %% [markdown]
# 1. Data exploration
# 2. Cleaning and handling the data outlier
# 3. Relationship amung the features
# 3. Visualization: Univariante and Bivariate Analysis

# %%
from pandas import*
import pandas as pd
from numpy import*
import numpy as np
from seaborn import*
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = read_csv('haberman.csv')
data.head(2)
# Out:
#    age  year  nodes  status
# 0   30    64      1       1
# 1   30    62      3       1

# %%
data.shape
# Out:
# (305, 4)

# %%
data.dtypes
# Out:
# age       int64
# year      int64
# nodes     int64
# status    int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# age       0
# year      0
# nodes     0
# status    0
# dtype: int64

# %% [markdown]
# #### Data exploration

# %%
data.columns
# Out:
# Index(['age', 'year', 'nodes', 'status'], dtype='object')

# %%
data['status'].value_counts()
# Out:
# 1    225
# 2     80
# Name: status, dtype: int64

# %%
sns.heatmap(data.isnull(),yticklabels = False)
# Out:
# <AxesSubplot:>

# %%
sns.set_style('whitegrid')
sns.countplot(x = "status",data = data)
# Out:
# <AxesSubplot:xlabel='status', ylabel='count'>

# %%
data.describe()
# Out:
#               age        year       nodes      status
# count  305.000000  305.000000  305.000000  305.000000
# mean    52.357377   62.868852    4.032787    1.262295
# std     10.678010    3.242783    7.200528    0.440605
# min     30.000000   58.000000    0.000000    1.000000
# 25%     44.000000   60.000000    0.000000    1.000000
# 50%     52.000000   63.000000    1.000000    1.000000
# 75%     60.000000   66.000000    4.000000    2.000000
# max     78.000000   69.000000   52.000000    2.000000

# %% [markdown]
# #### Bivariate Analysis

# %%
# Analysing two varibles 2D scatter plot

# %%
sns.set_style('whitegrid')
sns.FacetGrid(data,hue = 'status').map(plt.scatter,'age','year')

# %%
sns.set_style('darkgrid')
sns.FacetGrid(data,hue = 'status').map(plt.scatter,'age','year')

# %%
sns.set_style('ticks')
sns.FacetGrid(data,hue = 'status').map(plt.scatter,'age','year')

# %%
sns.set_style('dark')
sns.FacetGrid(data,hue = 'status').map(plt.scatter,'age','year')

# %%
sns.set_style('white')
sns.FacetGrid(data,hue = 'status').map(plt.scatter,'age','year')

# %%
sns.set_style('darkgrid')
sns.FacetGrid(data,hue = 'status').map(plt.scatter,'age','year').add_legend()

# %%
sns.set_style('darkgrid')
sns.FacetGrid(data,hue = 'status').map(plt.scatter,'age','nodes').add_legend()

# %%
sns.set_style('darkgrid')
sns.pairplot(data, hue = 'status', vars=['age','year','nodes'],palette = 'gist_rainbow')

# %% [markdown]
# #### Univariante

# %%
liv = data.loc[data['status'] == 1]
dead = data.loc[data['status'] == 2]


plt.plot(liv['age'],np.zeros_like(liv['age']),'o')
plt.plot(dead['age'],np.zeros_like(dead['age']),'o')
plt.show()#cumulative ditribution

# %%
plt.close()
sns.FacetGrid(data,hue='status').map(sns.distplot,'year').add_legend()
plt.show()
# Out:
# /home/m/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/m/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.displot(data['age'], color='lime')

# %%
sns.histplot(data['age'], color='green')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.boxenplot(x = 'status',y = 'age',data = data)
plt.show()

# %%
sns.boxplot(x = 'status',y = 'nodes',data = data)
plt.show()
